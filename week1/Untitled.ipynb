# %%
from matplotlib import pyplot as plt

# %%
x = np.linspace(-np.pi,np.pi,100)

# %%
c = np.cos(x)

# %%
s = np.sin(x)

# %%
plt.plot(x,c,'+')
plt.plot(x,s)
plt.show()

# %%
a
# Out:
# [1, 5, 3]

# %%
b
# Out:
# [1, 5, 3]
